# %%
class Node:
    def __init__(self, Value=None):
        self.Value = Value
        self.nextValue = None

class LinkedList:
    def __init__(self):
        self.header = None

    def listprint(self):
      #prints out the linked list starting from the header       
        printval = self.header       
        while printval is not None:
            print (printval.Value)
            printval = printval.nextValue
    
       def AtBegining(self,newdata):
        #inserts a new node at the beginning       
        NewNode = Node(newdata)
        NewNode.nextValue = self.header
        self.header = NewNode

        def AtEnd(self, newdata):
         #inserts a newnode in the end 
          NewNode = Node(newdata)          
          if self.header is None:
            self.header = NewNode
            return
          last = self.header
          while(last.nextValue):
            last = last.nextValue
          last.nextValue =NewNode
